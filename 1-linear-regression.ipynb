# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input/years-of-experience-and-salary-dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/years-of-experience-and-salary-dataset/Salary_Data.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
salary_data=pd.read_csv('/kaggle/input/years-of-experience-and-salary-dataset/Salary_Data.csv')
X=salary_data.iloc[:,:-1].values
y=salary_data.iloc[:,-1].values

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
salary_data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
sns.barplot(x='YearsExperience',y='Salary',data=salary_data)
# Out:
# <AxesSubplot:xlabel='YearsExperience', ylabel='Salary'>

# %%
sns.heatmap(salary_data.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=1/3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
plt.scatter(X_train,y_train,color='blue')
plt.plot(X_train,lr.predict(X_train),color="red")
plt.title("salary vs experience (Train set)")
plt.xlabel("Years of experience")
plt.ylabel("salary")
plt.show()

# %%
plt.scatter(X_test,y_test,color='blue')
plt.plot(X_train,lr.predict(X_train),color="red")
plt.title("salary vs experience (Test set)")
plt.xlabel("Years of experience")
plt.ylabel("salary")
plt.show()

# %%
#calculating residuals(errors)
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,y_pred))
print('MSE:',metrics.mean_squared_error(y_test,y_pred))
print("RMSE:",np.sqrt(metrics.mean_absolute_error(y_test,y_pred)))

# %% [markdown]
# mean absolute error,mean square error

# %% [markdown]
# Since RMSE(root mean squre error) value is less,the model is a good model

# %%
from sklearn import metrics
#calculating the residuals
print('y-intercept             :' , lr.intercept_)
print('beta coefficients       :' , lr.coef_)
print('Mean Abs Error MAE      :' ,metrics.mean_absolute_error(y_test,y_pred))
print('Mean Sqrt Error MSE     :' ,metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Sqrt Error RMSE:' ,np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
print('r2 value                :' ,metrics.r2_score(y_test,y_pred))
# Out:
# y-intercept             : 26816.192244031183
# beta coefficients       : [9345.94244312]
# Mean Abs Error MAE      : 3426.4269374307078
# Mean Sqrt Error MSE     : 21026037.329511296
# Root Mean Sqrt Error RMSE: 4585.4157204675885
# r2 value                : 0.9749154407708353
